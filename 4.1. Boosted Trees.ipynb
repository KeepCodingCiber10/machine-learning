# %% [markdown]
# # Boosted Trees
#
# Vamos a analizar el funcionamiento de los métodos de Gradient Boosting de sklearn mediante ejemplos ilustrativos.
#
# 1. Un problema de clasificación
# 2. Un problema de regresión
#
# Lo primero es cargar las librerías y funciones necesarias.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Un problema de clasificación
#
# Utilizaremos el [Pima Indian Diabetes dataset](https://www.kaggle.com/uciml/pima-indians-diabetes-database).
#
# <div class = "alert alert-success">
# EJERCICIO 6.1: Echa un vistazo al dataset y luego carga los datos almacenados en el fichero *diabetes.csv*
# </div>

# %%
# ... código aquí
data = pd.read_csv('./data/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Ahora podemos analizar un poco los datos: `.shape`, `.info`, `.describe()`, `.dtypes()`, `.isnull().any()`, etc.
#
# También es interesante estudiar la variable objetivo, `Outcome`, mediante `.value_counts()`.

# %%
data.shape
# Out:
# (768, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ### Análisis exploratorio básico
#
# Ya sabéis que habría que dividir, pero como licencia poética lo hago más adelante. Vamos a analizar.
#
# <div class = "alert alert-success">
# EJERCICIO 6.2: Represente el histograma de cada variable separando por clases, ¿hay alguna característica que convenga transformar?
# Nota: Si lo considera de utilidad, reutilice el código del Notebook anterior.
# </div>

# %%
data['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# ... código aquí
# Pintamos histogramas para cada clase
plt.figure(figsize=(20,10))

idx_0 =  data['Outcome'] == 0
idx_1 =  data['Outcome'] == 1

for i,feature in enumerate(data.columns.drop(['Outcome'])):
    plt.subplot(2,4,i+1)   
    plt.hist(data.loc[idx_0,feature],density=0, alpha=0.75,label='y=0')
    plt.hist(data.loc[idx_1,feature],density=0, facecolor='red', alpha=0.75,label='y=1')
    plt.legend()
    plt.title(feature)

plt.show()

# %% [markdown]
# Construyamos nuestro conjunto de test:

# %%
from sklearn.model_selection import train_test_split

# preparamos los datos
features = data.columns.drop(['Outcome'])
X = data[features].values
y = data['Outcome'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0, stratify=y)

print('Datos train: ', X_train.shape)
print('Datos test:  ', X_test.shape)
# Out:
# Datos train:  (614, 8)
# Datos test:   (154, 8)

# %% [markdown]
# <div class = "alert alert-success">
# EJERCICIO 6.3: ¿Qué diferencias hay si estratificamos? Calcula los porcentajes de la variable objetivo en ambos casos.
# </div>

# %%
# ... código aquí
# Porcentaje global
print('DISTRIBUCIÓN DEL DATASET ENTERO')
y = data['Outcome'].values
print(f'% ceros en total: {((np.unique(y, return_counts=True)[1][0]/y.shape[0])*100):.2f}')

# Sin estratificar
print('SIN ESTRATIFICAR')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)
print(f'% ceros en train: {((np.unique(y_train, return_counts=True)[1][0]/y_train.shape[0])*100):.2f}')
print(f'% ceros en test: {((np.unique(y_test, return_counts=True)[1][0]/y_test.shape[0])*100):.2f}')
      
# Estratificando
print('ESTRATIFICANDO')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0, stratify=y)
print(f'% ceros en train: {((np.unique(y_train, return_counts=True)[1][0]/y_train.shape[0])*100):.2f}')
print(f'% ceros en test: {((np.unique(y_test, return_counts=True)[1][0]/y_test.shape[0])*100):.2f}')
# Out:
# DISTRIBUCIÓN DEL DATASET ENTERO
# % ceros en total: 65.10
# SIN ESTRATIFICAR
# % ceros en train: 64.01
# % ceros en test: 69.48
# ESTRATIFICANDO
# % ceros en train: 65.15
# % ceros en test: 64.94

# %% [markdown]
# ### Decision trees
#
# Probemos primero con un árbol de decisión sencillo
#
# <div class = "alert alert-success">
# EJERCICIO 6.4: Entrena un árbol de decisión sencillo extrayendo el valor óptimo de `max_depth` entre 1 y 10, y muestra las prestaciones para el conjunto de test.
# </div>

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# ... código aquí
maxDepth = range(1,10)
param_grid = {'max_depth': maxDepth}
# ... código aquí
grid = GridSearchCV(DecisionTreeClassifier(), scoring='accuracy', param_grid=param_grid, cv=10, verbose=1)
grid.fit(X_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))

scores = np.array(grid.cv_results_['mean_test_score'])
plt.plot(maxDepth,scores,'-o')
plt.xlabel('max_depth',fontsize=16)
plt.ylabel('10-Fold MSE')
#plt.ylim((-1, 0))
plt.show()
# Out:
# Fitting 10 folds for each of 9 candidates, totalling 90 fits
# best mean cross-validation score: 0.738
# best parameters: {'max_depth': 3}

# %%
maxDepthOptimo = grid.best_params_['max_depth'] 
treeModel = DecisionTreeClassifier(max_depth=maxDepthOptimo).fit(X_train,y_train)

print("Train: ", treeModel.score(X_train, y_train))
print("Test: ", treeModel.score(X_test, y_test))
# Out:
# Train:  0.7671009771986971
# Test:  0.7987012987012987

# %% [markdown]
# Vamos a pintar el árbol:

# %%
from sklearn import tree

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(treeModel, feature_names=features, filled=True)

# %%
importances = treeModel.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),features[indices])
plt.show()

# %% [markdown]
# Parece un problema complicado de clasificar. Si queremos mejorar prestaciones tendremos que acudir a un modelo más complejo.
#
# ### Boosted Trees
#
# El entrenamiento del algoritmo de boosting requiere fijar tres parámetros libres:
#
# - Número de iteraciones
# - Tasa de aprendizaje ($\alpha$)
# - Complejidad del árbol: *max_depth*
#
# Se podría hacer una búsqueda sobre los tres parámetros conjuntamente mediante GridSearchCV, pero es muy costoso computacionalmente, con lo que es más sencillo aplicar una optimización secuencial: se prueban distintos valores de los parámetros libres, se fijan los óptimos y se busca sobre el resto.

# %%
list(range(3, 4))
# Out:
# [3]

# %%
from sklearn.ensemble import GradientBoostingClassifier

Niterations = [25,50,75,100,125,150,175,200,300]
learningRate = [0.5,0.1,0.05,0.01]
# mantenemos max_depth estático: max_depth=3

param_grid = {'n_estimators': Niterations,'learning_rate':learningRate, 'max_depth': list(range(3, 4)) }
grid = GridSearchCV(GradientBoostingClassifier(random_state=0), param_grid=param_grid, cv = 3, verbose=2)
grid.fit(X_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] END ....learning_rate=0.5, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ....learning_rate=0.5, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ....learning_rate=0.5, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.3s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.2s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.2s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=175; total time=   0.5s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.6s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=300; total time=   0.7s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=300; total time=   0.7s
# [CV] END ...learning_rate=0.5, max_depth=3, n_estimators=300; total time=   0.7s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time=   0.9s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=300; total time=   0.8s
# [CV] END ...learning_rate=0.05, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.05, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.05, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.05, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=300; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=300; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=300; total time=   0.7s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   0.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=125; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=150; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=150; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=175; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=175; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=300; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=300; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=300; total time=   0.7s
# best mean cross-validation score: 0.752
# best parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}

# %% [markdown]
# Representemos el error que estamos cometiendo para los distintos valores de los parámetros libres

# %%
# calculamos métricas globales
lrOptimo = grid.best_params_['learning_rate']
neOptimo = grid.best_params_['n_estimators']
bt = GradientBoostingClassifier(random_state=0, max_depth=3,learning_rate=lrOptimo, n_estimators=neOptimo)
bt.fit(X_train,y_train)

error = 1-grid.cv_results_['mean_test_score'].reshape(len(learningRate),len(Niterations))
colors = ['r','b','g','k','m']
for i,lr in enumerate(learningRate):    
    plt.plot(Niterations,error[i,:],colors[i] + '--o',label='lr = %g'%lr)

plt.legend()
plt.xlabel('# árboles')
plt.ylabel('5-fold CV Error')
plt.title('train: %0.3f\ntest:  %0.3f'%(bt.score(X_train,y_train),bt.score(X_test,y_test)))
plt.grid()
plt.show()

# %% [markdown]
# Las prestaciones no son mucho mejores que con respecto a un árbol sencillo. Como el coste de entrenamiento de este conjunto no es muy grande, replicaremos el análisis anterior aumentando el valor de la complejidad.

# %%
# Niterations = [25,50,75,100,125,150,175,200,300]
# learningRate = [0.5,0.1,0.05,0.01]

Niterations = [75, 100, 200, 300, 500, 1000]
learningRate = [0.5, 0.1, 0.05, 0.01]
# mantenemos max_depth estático: max_depth=3

param_grid = {'n_estimators': Niterations,'learning_rate':learningRate }
grid = GridSearchCV(GradientBoostingClassifier(random_state=0, max_depth=3), param_grid=param_grid, cv=3, verbose=2)
grid.fit(X_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV] END .................learning_rate=0.5, n_estimators=75; total time=   0.2s
# [CV] END .................learning_rate=0.5, n_estimators=75; total time=   0.2s
# [CV] END .................learning_rate=0.5, n_estimators=75; total time=   0.2s
# [CV] END ................learning_rate=0.5, n_estimators=100; total time=   0.2s
# [CV] END ................learning_rate=0.5, n_estimators=100; total time=   0.2s
# [CV] END ................learning_rate=0.5, n_estimators=100; total time=   0.2s
# [CV] END ................learning_rate=0.5, n_estimators=200; total time=   0.5s
# [CV] END ................learning_rate=0.5, n_estimators=200; total time=   0.5s
# [CV] END ................learning_rate=0.5, n_estimators=200; total time=   0.5s
# [CV] END ................learning_rate=0.5, n_estimators=300; total time=   0.8s
# [CV] END ................learning_rate=0.5, n_estimators=300; total time=   0.7s
# [CV] END ................learning_rate=0.5, n_estimators=300; total time=   0.7s
# [CV] END ................learning_rate=0.5, n_estimators=500; total time=   1.1s
# [CV] END ................learning_rate=0.5, n_estimators=500; total time=   1.1s
# [CV] END ................learning_rate=0.5, n_estimators=500; total time=   1.2s
# [CV] END ...............learning_rate=0.5, n_estimators=1000; total time=   1.2s
# [CV] END ...............learning_rate=0.5, n_estimators=1000; total time=   1.7s
# [CV] END ...............learning_rate=0.5, n_estimators=1000; total time=   1.3s
# [CV] END .................learning_rate=0.1, n_estimators=75; total time=   0.2s
# [CV] END .................learning_rate=0.1, n_estimators=75; total time=   0.2s
# [CV] END .................learning_rate=0.1, n_estimators=75; total time=   0.2s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   0.2s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   0.2s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   0.2s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time=   0.5s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time=   0.5s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time=   0.5s
# [CV] END ................learning_rate=0.1, n_estimators=300; total time=   0.6s
# [CV] END ................learning_rate=0.1, n_estimators=300; total time=   0.6s
# [CV] END ................learning_rate=0.1, n_estimators=300; total time=   0.6s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   1.0s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   1.0s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   0.9s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   1.9s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   1.9s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   1.9s
# [CV] END ................learning_rate=0.05, n_estimators=75; total time=   0.1s
# [CV] END ................learning_rate=0.05, n_estimators=75; total time=   0.2s
# [CV] END ................learning_rate=0.05, n_estimators=75; total time=   0.1s
# [CV] END ...............learning_rate=0.05, n_estimators=100; total time=   0.2s
# [CV] END ...............learning_rate=0.05, n_estimators=100; total time=   0.2s
# [CV] END ...............learning_rate=0.05, n_estimators=100; total time=   0.2s
# [CV] END ...............learning_rate=0.05, n_estimators=200; total time=   0.4s
# [CV] END ...............learning_rate=0.05, n_estimators=200; total time=   0.4s
# [CV] END ...............learning_rate=0.05, n_estimators=200; total time=   0.4s
# [CV] END ...............learning_rate=0.05, n_estimators=300; total time=   0.5s
# [CV] END ...............learning_rate=0.05, n_estimators=300; total time=   0.6s
# [CV] END ...............learning_rate=0.05, n_estimators=300; total time=   0.5s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=   0.9s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=   0.9s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=   0.9s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=   1.8s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=   1.9s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=   1.9s
# [CV] END ................learning_rate=0.01, n_estimators=75; total time=   0.1s
# [CV] END ................learning_rate=0.01, n_estimators=75; total time=   0.2s
# [CV] END ................learning_rate=0.01, n_estimators=75; total time=   0.1s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   0.2s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   0.2s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   0.2s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time=   0.4s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time=   0.4s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time=   0.4s
# [CV] END ...............learning_rate=0.01, n_estimators=300; total time=   0.6s
# [CV] END ...............learning_rate=0.01, n_estimators=300; total time=   0.6s
# [CV] END ...............learning_rate=0.01, n_estimators=300; total time=   0.6s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   0.9s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   1.0s
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   1.0s
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   1.9s
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   1.9s
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   1.9s
# best mean cross-validation score: 0.752
# best parameters: {'learning_rate': 0.1, 'n_estimators': 75}

# %%
# calculamos métricas globales
lrOptimo = grid.best_params_['learning_rate']
neOptimo = grid.best_params_['n_estimators']
bt = GradientBoostingClassifier(random_state=0, max_depth=3,learning_rate=lrOptimo, n_estimators=neOptimo)
bt.fit(X_train,y_train)

error = 1-grid.cv_results_['mean_test_score'].reshape(len(learningRate),len(Niterations))
colors = ['r','b','g','k','m']
for i,lr in enumerate(learningRate):    
    plt.plot(Niterations,error[i,:],colors[i] + '--o',label='lr = %g'%lr)

plt.legend()
plt.xlabel('# iteraciones')
plt.ylabel('5-fold CV Error')
plt.title('train: %0.3f\ntest:  %0.3f'%(bt.score(X_train,y_train),bt.score(X_test,y_test)))
plt.grid()
plt.show()

# %% [markdown]
# Vemos que al aumentar la complejidad, necesitamos una tasa de aprendizaje más pequeña. En general, cuanto más complejo es el problema, menor es la tasa de aprendizaje y mayor el número de iteraciones que necesita el algoritmo. Parece que podemos ir un poco más allá, disminuyamos un poco más la tasa de aprendizaje

# %%
# Niterations = [25,50,75,100,125,150,175,200,300]
# learningRate = [0.5,0.1,0.05,0.01]

# Niterations = [75, 100, 200, 300, 500, 1000]
# learningRate = [0.5, 0.1, 0.05, 0.01]


Niterations = [75, 100, 200, 300, 500, 1000]
learningRate = [0.5, 0.1, 0.05, 0.01, 0.005]
# mantenemos max_depth estático: max_depth=3

param_grid = {'n_estimators': Niterations,'learning_rate':learningRate}
grid = GridSearchCV(GradientBoostingClassifier(random_state=0, max_depth=3), param_grid=param_grid, cv=3, verbose=2)
grid.fit(X_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))
# Out:
# best mean cross-validation score: 0.752
# best parameters: {'learning_rate': 0.1, 'n_estimators': 75}

# %%
# calculamos métricas globales
lrOptimo = grid.best_params_['learning_rate']
neOptimo = grid.best_params_['n_estimators']
bt = GradientBoostingClassifier(random_state=0, max_depth=3,learning_rate=lrOptimo, n_estimators=neOptimo)
bt.fit(X_train,y_train)

error = 1-grid.cv_results_['mean_test_score'].reshape(len(learningRate),len(Niterations))
colors = ['r','b','g','k','m']
for i,lr in enumerate(learningRate):    
    plt.plot(Niterations,error[i,:],colors[i] + '--o',label='lr = %g'%lr)

plt.legend()
plt.xlabel('# iteraciones')
plt.ylabel('5-fold CV Error')
plt.title('train: %0.3f\ntest:  %0.3f'%(bt.score(X_train,y_train),bt.score(X_test,y_test)))
plt.grid()
plt.show()

# %% [markdown]
# Hemos visto un ejemplo de representación de barrido con GridSearch sobre dos parámetros. Cuidado con hacer barridos sobre muchos parámetros, porque luego no podremos visualizar! Aquí tenéis [un ejemplo sobre dos dimensiones](https://stackoverflow.com/a/43645640) y aquí uno [sobre tres](https://stackoverflow.com/a/55766938/4346986).
#
# Podemos representar también la importancia de las variables:
#
# <div class = "alert alert-success">
# EJERCICIO 6.5: Representa la importancia de las variables.
# </div>

# %%
# ... código aquí
importances = bt.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),features[indices])
plt.show()

# %% [markdown]
# # 2. Un problema de regresión
#
# Volvemos a nuestro conjunto de datos ya conocido:

# %%
# cargamos datos
house_data = pd.read_csv("./data/kc_house_data.csv") # cargamos fichero

# Eliminamos las columnas id y date 
house_data = house_data.drop(['id','date'], axis=1)

# convertir las variables en pies al cuadrado en metros al cuadrado 
feetFeatures = ['sqft_living','sqft_lot','sqft_above','sqft_basement','sqft_living15','sqft_lot15']
house_data[feetFeatures] = house_data[feetFeatures].apply(lambda x: x * 0.3048 * 0.3048)

# renombramos
house_data.columns = ['price','bedrooms','bathrooms','sqm_living','sqm_lot','floors','waterfront','view','condition',
                      'grade','sqm_above','sqm_basement','yr_built','yr_renovated','zip_code','lat','long',
                      'sqm_living15','sqm_lot15']

# añadimos las nuevas variables
house_data['years']            = 2017 - house_data['yr_built']
house_data['bedrooms_squared'] = house_data['bedrooms'].apply(lambda x: x**2)
house_data['bed_bath_rooms']   = house_data['bedrooms']*house_data['bathrooms']
house_data['log_sqm_living']   = house_data['sqm_living'].apply(lambda x: np.log(x))
house_data['lat_plus_long']    = house_data['lat']*house_data['long']

# convertimos el DataFrame al formato necesario para scikit-learn
data = house_data.values

y = data[:,0:1]     # nos quedamos con la 1ª columna, price
X = data[:,1:]      # nos quedamos con el resto

feature_names = house_data.columns[1:]

# Dividimos los datos en entrenamiento y test (80 training, 20 test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state = 2)

print('Datos entrenamiento: ', X_train.shape)
print('Datos test: ', X_test.shape)
# Out:
# Datos entrenamiento:  (16209, 23)
# Datos test:  (5404, 23)

# %% [markdown]
# Dado que el número de muestras del problema es mayor, y para no extender el entrenamiento, escogeremos de forma muy secuencial los parámetros libres.
#
# AVISO: Este proceso va a tardar un rato ...

# %%
from sklearn.ensemble import GradientBoostingRegressor

Niterations = [500,1000,1500,2000]
learningRate = [0.1,0.05]
# mantenemos max_depth estático: max_depth=3

param_grid = {'n_estimators': Niterations,'learning_rate':learningRate}
grid = GridSearchCV(GradientBoostingRegressor(random_state=0, max_depth=3), param_grid=param_grid, cv=3, verbose=2)
grid.fit(X_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  34.4s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  35.7s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  34.7s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time= 1.0min
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time= 1.0min
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time= 1.0min
# [CV] END ...............learning_rate=0.1, n_estimators=1500; total time= 1.4min
# [CV] END ...............learning_rate=0.1, n_estimators=1500; total time= 1.4min
# [CV] END ...............learning_rate=0.1, n_estimators=1500; total time= 1.2min
# [CV] END ...............learning_rate=0.1, n_estimators=2000; total time= 1.9min
# [CV] END ...............learning_rate=0.1, n_estimators=2000; total time= 1.9min
# [CV] END ...............learning_rate=0.1, n_estimators=2000; total time= 1.8min
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=  21.5s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=  29.2s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=  28.4s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time= 1.0min
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time= 1.2min
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time= 1.2min
# [CV] END ..............learning_rate=0.05, n_estimators=1500; total time= 1.9min
# [CV] END ..............learning_rate=0.05, n_estimators=1500; total time= 1.7min
# [CV] END ..............learning_rate=0.05, n_estimators=1500; total time= 1.7min
# [CV] END ..............learning_rate=0.05, n_estimators=2000; total time= 2.3min
# [CV] END ..............learning_rate=0.05, n_estimators=2000; total time= 2.5min
# [CV] END ..............learning_rate=0.05, n_estimators=2000; total time= 1.9min
# best mean cross-validation score: 0.890
# best parameters: {'learning_rate': 0.05, 'n_estimators': 2000}

# %%
lrOptimo = grid.best_params_['learning_rate']
neOptimo = grid.best_params_['n_estimators']
bt = GradientBoostingRegressor(random_state=0, max_depth=3,learning_rate=lrOptimo, n_estimators=neOptimo)
bt.fit(X_train,y_train)

error = 1-grid.cv_results_['mean_test_score'].reshape(len(learningRate),len(Niterations))
colors = ['r','b','g','k','m']
for i,lr in enumerate(learningRate):    
    plt.plot(Niterations,error[i,:],colors[i] + '--o',label='lr = %g'%lr)

plt.legend()
plt.xlabel('# iteraciones')
plt.ylabel('5-fold CV Error')
plt.title('train: %0.3f\ntest:  %0.3f'%(bt.score(X_train,y_train),bt.score(X_test,y_test)))
plt.grid()
plt.show()

# %%
lrOptimo = grid.best_params_['learning_rate']
neOptimo = grid.best_params_['n_estimators']
baggingModel = GradientBoostingRegressor(max_depth=3, n_estimators=neOptimo, learning_rate=lrOptimo).fit(X_train,y_train)

print("Train: ",baggingModel.score(X_train,y_train))
print("Test: ",baggingModel.score(X_test,y_test))
# Out:
# Train:  0.9603343223772384
# Test:  0.8993152705541344

# %% [markdown]
# ### Importancia de las variables

# %%
importances = bt.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),feature_names[indices])
plt.show()

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

Niterations = [500,1000,1500,2000]
learningRate = [0.1,0.05]
# mantenemos max_depth estático: max_depth=3

param_grid = {'n_estimators': Niterations,'learning_rate':learningRate}
grid = GridSearchCV(AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3), random_state=0), param_grid=param_grid, cv=3, verbose=2)
grid.fit(X_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  22.6s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  20.9s
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=  13.5s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=  31.6s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=  26.0s
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=  35.1s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=  23.1s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=  23.8s
# [CV] END ...............learning_rate=0.05, n_estimators=500; total time=  23.5s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=  35.0s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=  32.2s
# [CV] END ..............learning_rate=0.05, n_estimators=1000; total time=  39.5s
# best mean cross-validation score: 0.575
# best parameters: {'learning_rate': 0.05, 'n_estimators': 500}

# %%
lrOptimo = grid.best_params_['learning_rate']
neOptimo = grid.best_params_['n_estimators']
ada_boost_model = AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3), learning_rate=lrOptimo, n_estimators=neOptimo)
ada_boost_model.fit(X_train,y_train)

error = 1-grid.cv_results_['mean_test_score'].reshape(len(learningRate),len(Niterations))
colors = ['r','b','g','k','m']
for i,lr in enumerate(learningRate):    
    plt.plot(Niterations,error[i,:],colors[i] + '--o',label='lr = %g'%lr)

plt.legend()
plt.xlabel('# iteraciones')
plt.ylabel('5-fold CV Error')
plt.title('train: %0.3f\ntest:  %0.3f'%(ada_boost_model.score(X_train,y_train), ada_boost_model.score(X_test,y_test)))
plt.grid()
plt.show()

# %%
lrOptimo = grid.best_params_['learning_rate']
neOptimo = grid.best_params_['n_estimators']
ada_boost_model = AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3), n_estimators=neOptimo, learning_rate=lrOptimo).fit(X_train,y_train)

print("Train: ",ada_boost_model.score(X_train,y_train))
print("Test: ",ada_boost_model.score(X_test,y_test))
# Out:
# Train:  0.5978850325495109
# Test:  0.5630534105650749

# %%
importances = ada_boost_model.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),feature_names[indices])
plt.show()

# %% [markdown]
# ### What's next?
#
# Así que, ¿qué más podríamos hacer? aumentar *max_depth*, pero seguramente incurramos en overfitting. Aquí radica el arte del *machine learning*:
#
# 1. Conoce el problema (negocio), para generar nuevas *features* de interés
# 2. Trata de buscar más ejemplos para utilizar técnicas de aprendizaje profundo
